# %% [markdown]
# # **1.Importing neccessary libraries**

# %%
#importing neccessary libraries
import pandas as pd

# %% [markdown]
# # **2.Reading csv file, taking user input and listing the description**

# %%
#reading csv file, taking user input and listing the tags
df = pd.read_csv("final.csv")
def combined_features(row):
    return str(row['Title'])+" "+str(row['Description'])+" "+str(row['Author'])
df["combined_features"] = df.apply(combined_features, axis =1)
# desc_arr = list(df["Description"])
#print(desc_arr)
s=input("Enter your book description : ")
s=s.lower()
#removing the unneccesary words
s=s+' ' 
arr=['books','book','best','recommend','for','in','market','of','seller','by','buy','author','written','show','other','the','me','all','what','are','world','get','rating']
x=""
y=""
for i in range(0,len(s)):
    if(s[i]!=' '):
        x=x+s[i]
    else:
        if(arr.count(x)==0):
            y=y+x+' '
        x=""
s=y
df
# Out:
#                                                  Title   Price Rating  \
# 0                                 Handbook Mathematics  $38.49    4.4
# 1                                    Vedic Mathematics  $13.99    4.2
# 2    Cambridge Primary Mathematics Learner's Book 2...  $18.52    4.9
# 3    Cambridge Lower Secondary Mathematics Learner'...  $42.35    4.8
# 4    Cambridge Lower Secondary Mathematics Learner'...  $42.35    4.8
# ..                                                 ...     ...    ...
# 301                                  Pride & Prejudice  $13.50    4.6
# 302                                A Tale Of Two Souls  $11.99    4.3
# 303  One Day, Life Will Change: A story of love and...   $8.99    4.4
# 304         The Malhotra Bride (Core List, Bestseller)   $7.99    3.8
# 305                                        Just Missed  $10.99    4.2
#
#                                            Description               Author  \
# 0    Mathematics of higher level has too many theor...              Unknown
# 1    Vedic Mathematics: The Problem Solver contains...          Maple Press
# 2    Discover our new resources for the Cambridge I...       Cherri Moseley
# 3    Whether you're learning about distance, area a...            Lynn Byrd
# 4    Whether you're learning about decimals, percen...            Lynn Byrd
# ..                                                 ...                  ...
# 301  When Elizabeth Bennet meets Fitzwilliam Darcy ...          Jane Austen
# 302  I thought it was all over until I met her agai...          Anand Kumar
# 303  Love... does it mean running around the trees ...   Saranya Umakanthan
# 304  She is young, ravishing and free-spirited. He ...  Sundari Venkatraman
# 305  Siddharth aka Mr. Perfectionist is married to ...      Himanshu Bhatia
#
#                                                   LINK  \
# 0    https://www.amazon.com/Handbook-Mathematics-Ar...
# 1    https://www.amazon.com/Vedic-Mathematics-India...
# 2    https://www.amazon.com/Cambridge-Primary-Mathe...
# 3    https://www.amazon.com/Cambridge-Secondary-Mat...
# 4    https://www.amazon.com/Cambridge-Secondary-Mat...
# ..                                                 ...
# 301  https://www.amazon.com/Pride-Prejudice-Jane-Au...
# 302  https://www.amazon.com/tale-two-Souls-Anand-Ku...
# 303  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 304  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 305  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
#
#                                      combined_features
# 0    Handbook Mathematics Mathematics of higher lev...
# 1    Vedic Mathematics Vedic Mathematics: The Probl...
# 2    Cambridge Primary Mathematics Learner's Book 2...
# 3    Cambridge Lower Secondary Mathematics Learner'...
# 4    Cambridge Lower Secondary Mathematics Learner'...
# ..                                                 ...
# 301  Pride & Prejudice When Elizabeth Bennet meets ...
# 302  A Tale Of Two Souls I thought it was all over ...
# 303  One Day, Life Will Change: A story of love and...
# 304  The Malhotra Bride (Core List, Bestseller) She...
# 305  Just Missed Siddharth aka Mr. Perfectionist is...
#
# [306 rows x 7 columns]

# %% [markdown]
# # **3.Lisitng the details of the books**

# %%
#listing the name of the books
title_arr=list(df["Title"])
price_arr=list(df["Price"])
rating_arr=list(df["Rating"])
author_arr=list(df["Author"])
url_arr=list(df["LINK"])
comb_arr=list(df["combined_features"])

# %% [markdown]
# # **4.Implementing the Jaccard similarity**

# %%
#implementing the Jaccard similarity
def Jaccard_Similarity(doc1, doc2): 
    
    # List the unique words in a document
    words_doc1 = set(doc1.lower().split()) 
    words_doc2 = set(doc2.lower().split())
    
    # Find the intersection of words list of doc1 & doc2
    intersection = words_doc1.intersection(words_doc2)

    # Find the union of words list of doc1 & doc2
    union = words_doc1.union(words_doc2)
        
    # Calculate Jaccard similarity score 
    # using length of intersection set divided by length of union set
    return float(len(intersection)) / len(union)

# %% [markdown]
# # **5.Calling the Jaccard_Similarity for calculating the similarity**

# %%
#calling the Jaccard_Similarity for calculating the similarity
similar=[]
add=0 #variable to check whether atleast one recommendation is there or not
for item in comb_arr:
    similar.append(Jaccard_Similarity(item,s))
    jc=Jaccard_Similarity(item,s)
    add=add+jc

# %% [markdown]
# # **6.Storing the deatils of each book in an array**

# %%
#storing the deatils of each book in an array
reco=[]
for i in range(0,len(title_arr)):
    #print(title_arr[i]+"  "+str(similar[i]))
    pair=((similar[i],title_arr[i],price_arr[i],author_arr[i],rating_arr[i],url_arr[i]))
    reco.append(pair)

# %% [markdown]
# # **7.Printing the recommended books**

# %%
#printing the recommended books
l=[]
ans=[]
reco.sort(reverse=True)
count=0
if add==0:
    print("No relevant recommendation !!")
if add!=0:
    print("Your search matched with the following books ")
    for item in reco:
        if(item[0]>0):
            l=[]
            l.append(item[1])
            l.append(item[3])
            l.append(item[2])
            l.append(item[4])
            l.append(item[5])
            ans.append(l)
            
ans.sort(key=lambda x:x[3],reverse=True)
print("Title                           Author                   Price                           Rating                           Url")
i=1
for item in ans:
    for item1 in item:
        print(item1,end=",")
        i=i+1
    print(end="\n")
# Out:
# Your search matched with the following books
# Title                           Author                   Price                           Rating                           Url
# The C++ Programming Language, 4th Edition,Bjarne Stroustrup,$78.68,4.6,https://www.amazon.com/C-Programming-Language-Bjarne-Stroustrup/dp/0321563840/ref=sr_1_12?keywords=C%2B%2B+books&qid=1680598613&s=books&sr=1-12,
# C++ High Performance: Master the art of optimizing the functioning of your C++ code, 2nd Edition,Bjorn Andrist,$57.99,4.6,https://www.amazon.com/High-Performance-Master-optimizing-functioning/dp/1839216549/ref=sr_1_6?keywords=C%2B%2B+books&qid=1680598613&s=books&sr=1-6,
